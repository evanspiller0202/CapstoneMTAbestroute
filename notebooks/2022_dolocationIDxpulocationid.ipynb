# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyarrow

# %%
rideshares = pd.read_parquet(r'C:\Users\EvanSpiller\Documents\DS BootCamp\Capstone\data\HVFHV_Compressed\Combined\full_compressed_HVFHV_2019_2020.parquet')

# %%
rideshares2019Q4morning = rideshares.loc[
    (
       ((rideshares['Month'] == 10) |(rideshares['Month'] == 11) | (rideshares['Month'] == 12)) &
    ((rideshares['Year'] == 2019) | (rideshares['Year'] == 2022))
     & ((rideshares['Hour']>=7) & (rideshares['Hour']<=10))
    )
]

# %%
rideshares = pd.read_parquet(r'C:\Users\EvanSpiller\Documents\DS BootCamp\Capstone\data\HVFHV_Compressed\Combined\full_compressed_HVFHV_2022_2023')
rideshares2022Q4morning = rideshares.loc[
    (
       ((rideshares['Month'] == 10) |(rideshares['Month'] == 11) | (rideshares['Month'] == 12)) &
    ((rideshares['Year'] == 2019) | (rideshares['Year'] == 2022))
     & ((rideshares['Hour']>=7) & (rideshares['Hour']<=10))
    )
]

# %%
morningcommutesq420192022 = pd.concat([rideshares2022Q4morning, rideshares2019Q4morning], axis=0)

# %%
zones.columns
# Out:
# Index(['LocationID', 'Borough', 'Zone', 'service_zone'], dtype='object')

# %%
zones = pd.read_csv(r'C:\Users\EvanSpiller\Documents\DS BootCamp\Capstone\data\taxi+_zone_lookup.csv')

# %%
morningcommutesq420192022 = pd.merge(morningcommutesq420192022, zones, left_on='DOLocationID', right_on='LocationID', how='inner')

# %%
morningcommutesq420192022manhattan = morningcommutesq420192022.loc[morningcommutesq420192022['Borough']=='Manhattan',:]

# %%
morningcommutesq420192022manhattan
# Out:
#          PULocationID  DOLocationID  Year  Month  Day  Hour  trip_miles_sum  \
# 22045               4             1  2022     10    1     7          15.730
# 22046               4             1  2022     10    1     8          28.266
# 22047               4             1  2022     10    1     9          14.600
# 22048               4             1  2022     10    2     7          13.870
# 22049               4             1  2022     10    2     8          30.590
# ...               ...           ...   ...    ...  ...   ...             ...
# 6944496           263           265  2019     12   31     9          67.093
# 6944497           263           265  2019     12   31    10          36.597
# 6945735           105           255  2019     11    8     8           4.130
# 6945736           105            45  2019     12    6    10           1.430
# 6945737           105           132  2019     12   24     8          26.860
#
#          congestion_surcharge_sum  tips_sum  driver_pay_sum  trips  \
# 22045                        0.00      3.00           42.05      1
# 22046                        0.00      5.00           70.16      2
# 22047                        0.00     15.38           38.58      1
# 22048                        0.00      0.00           34.65      1
# 22049                        0.00      0.00           74.59      2
# ...                           ...       ...             ...    ...
# 6944496                      8.25     12.69          140.38      3
# 6944497                      5.50      0.00           73.75      2
# 6945735                      0.75      0.00            0.00      1
# 6945736                      2.75      1.00            8.46      1
# 6945737                      0.00      9.00           70.60      1
#
#          LocationID    Borough                                           Zone  \
# 22045             4  Manhattan                                  Alphabet City
# 22046             4  Manhattan                                  Alphabet City
# 22047             4  Manhattan                                  Alphabet City
# 22048             4  Manhattan                                  Alphabet City
# 22049             4  Manhattan                                  Alphabet City
# ...             ...        ...                                            ...
# 6944496         263  Manhattan                                 Yorkville West
# 6944497         263  Manhattan                                 Yorkville West
# 6945735         105  Manhattan  Governor's Island/Ellis Island/Liberty Island
# 6945736         105  Manhattan  Governor's Island/Ellis Island/Liberty Island
# 6945737         105  Manhattan  Governor's Island/Ellis Island/Liberty Island
#
#         service_zone
# 22045    Yellow Zone
# 22046    Yellow Zone
# 22047    Yellow Zone
# 22048    Yellow Zone
# 22049    Yellow Zone
# ...              ...
# 6944496  Yellow Zone
# 6944497  Yellow Zone
# 6945735  Yellow Zone
# 6945736  Yellow Zone
# 6945737  Yellow Zone
#
# [2319325 rows x 15 columns]

# %%
groupby = morningcommutesq420192022manhattan.groupby(['PULocationID','Year'])['trips'].sum()

# %%
groupby = groupby.unstack()

# %%
groupby = groupby.reset_index()

# %%
groupby.to_csv(r'C:\Users\EvanSpiller\Documents\DS BootCamp\Capstone\data\morningcommutestomanhattanq4comparison.csv', index=False)
