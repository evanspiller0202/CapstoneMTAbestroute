# %%
import numpy as np
import pandas as pd

# %%
import pyarrow

# %%
def compression(file):
    rideshares = pd.read_parquet(file)
    rideshares['Month'] = rideshares['dropoff_datetime'].dt.month
    rideshares['Day'] = rideshares['dropoff_datetime'].dt.day
    rideshares['Hour'] = rideshares['dropoff_datetime'].dt.hour
    rideshares['Year'] = rideshares['dropoff_datetime'].dt.year
    rideshares_grouped = rideshares.groupby(['PULocationID', 'DOLocationID', 'Year', 'Month', 'Day', 'Hour']).agg(
        trip_miles_sum=pd.NamedAgg(column='trip_miles', aggfunc='sum'),
        congestion_surcharge_sum=pd.NamedAgg(column='congestion_surcharge', aggfunc='sum'),
        tips_sum=pd.NamedAgg(column='tips', aggfunc='sum'),
        driver_pay_sum=pd.NamedAgg(column='driver_pay', aggfunc='sum'),
        trips=pd.NamedAgg(column='trip_miles', aggfunc='count')
    )
    rideshares_grouped = rideshares_grouped.reset_index()
    new_file_path = r'C:\Users\EvanSpiller\Documents\DS BootCamp\Capstone\data\HVFHV_Compressed\compressed_HVFHV_' + year_month
    rideshares_grouped.to_parquet(new_file_path, engine='pyarrow')

# %%
# Empty list to store the results
year_month_list = []

# Loop through years from 2019 to 2022
for year in range(2020, 2023):
    # Loop through months from 1 to 12
    for month in range(1, 13):
        # Format the year and month as "YYYY-MM" and append to the list
        year_month_list.append(f"{year}-{month:02d}")

# The list `year_month_list` will now contain all years and months from 2019 to 2022 in the desired format
year_month_list
# Out:
# ['2020-01',
#  '2020-02',
#  '2020-03',
#  '2020-04',
#  '2020-05',
#  '2020-06',
#  '2020-07',
#  '2020-08',
#  '2020-09',
#  '2020-10',
#  '2020-11',
#  '2020-12',
#  '2021-01',
#  '2021-02',
#  '2021-03',
#  '2021-04',
#  '2021-05',
#  '2021-06',
#  '2021-07',
#  '2021-08',
#  '2021-09',
#  '2021-10',
#  '2021-11',
#  '2021-12',
#  '2022-01',
#  '2022-02',
#  '2022-03',
#  '2022-04',
#  '2022-05',
#  '2022-06',
#  '2022-07',
#  '2022-08',
#  '2022-09',
#  '2022-10',
#  '2022-11',
#  '2022-12']

# %%
for year_month in year_month_list:
    file = "https://d37ci6vzurychx.cloudfront.net/trip-data/fhvhv_tripdata_" + year_month + ".parquet"
    compression(file)

# %%
# Empty list to store the results
year_month_list = []

# Loop through years from 2019 to 2022
for year in range(2019,2020):
    # Loop through months from 1 to 12
    for month in range(1, 13):
        # Format the year and month as "YYYY-MM" and append to the list
        year_month_list.append(f"{year}-{month:02d}")

# The list `year_month_list` will now contain all years and months from 2019 to 2022 in the desired format
year_month_list = ['2019-02',
 '2019-03',
 '2019-04',
 '2019-05',
 '2019-06',
 '2019-07',
 '2019-08',
 '2019-09',
 '2019-10',
 '2019-11',
 '2019-12']

# %%
for year_month in year_month_list:
    file = "https://d37ci6vzurychx.cloudfront.net/trip-data/fhvhv_tripdata_" + year_month + ".parquet"
    compression(file)

# %%
year_month_list = []
for year in range(2019,2024):
    # Loop through months from 1 to 12
    for month in range(1, 13):
        # Format the year and month as "YYYY-MM" and append to the list
        year_month_list.append(f"{year}-{month:02d}")

# The list `year_month_list` will now contain all years and months from 2019 to 2022 in the desired format
#HVFHV data starts in Feb 2019 and goes to april 2023.
year_month_list =  ['2019-02',
 '2019-03',
 '2019-04',
 '2019-05',
 '2019-06',
 '2019-07',
 '2019-08',
 '2019-09',
 '2019-10',
 '2019-11',
 '2019-12',
 '2020-01',
 '2020-02',
 '2020-03',
 '2020-04',
 '2020-05',
 '2020-06',
 '2020-07',
 '2020-08',
 '2020-09',
 '2020-10',
 '2020-11',
 '2020-12',
 '2021-01',
 '2021-02',
 '2021-03',
 '2021-04',
 '2021-05',
 '2021-06',
 '2021-07',
 '2021-08',
 '2021-09',
 '2021-10',
 '2021-11',
 '2021-12',
 '2022-01',
 '2022-02',
 '2022-03',
 '2022-04',
 '2022-05',
 '2022-06',
 '2022-07',
 '2022-08',
 '2022-09',
 '2022-10',
 '2022-11',
 '2022-12',
 '2023-01',
 '2023-02',
 '2023-03',
 '2023-04']

# %%
print(year_month_list)
# Out:
# ['2019-02', '2019-03', '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03', '2021-04', '2021-05', '2021-06', '2021-07', '2021-08', '2021-09', '2021-10', '2021-11', '2021-12', '2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06', '2022-07', '2022-08', '2022-09', '2022-10', '2022-11', '2022-12', '2023-01', '2023-02', '2023-03', '2023-04']

# %%
for year_month in year_month_list:
    new_file_path = r"C:\Users\EvanSpiller\Documents\DS BootCamp\Capstone\data\HVFHV_Compressed\compressed_HVFHV_" + year_month
    df = pd.read_parquet(new_file_path)
    shape = df.shape
    print(year_month,",",shape[0])
#just looking to see how big I can reasonably make the groupings. I think two years at a time will work.
# Out:
# 2019-02 , 6447091
# 2019-03 , 7480020
# 2019-04 , 7020231
# 2019-05 , 7182380
# 2019-06 , 6899404
# 2019-07 , 6857375
# 2019-08 , 6922793
# 2019-09 , 6713666
# 2019-10 , 6907533
# 2019-11 , 6878251
# 2019-12 , 7013408
# 2020-01 , 6728272
# 2020-02 , 6714450
# 2020-03 , 5145110
# 2020-04 , 2658678
# 2020-05 , 3522982
# 2020-06 , 4094492
# 2020-07 , 5006918
# 2020-08 , 5392083
# 2020-09 , 5602243
# 2020-10 , 5863761
# 2020-11 , 5321542
# 2020-12 , 5287741
# 2021-01 , 5426415
# 2021-02 , 5104301
# 2021-03 , 6135044
# 2021-04 , 6046947
# 2021-05 , 6302712
# 2021-06 , 6281523
# 2021-07 , 6351125
# 2021-08 , 6247082
# 2021-09 , 6149096
# 2021-10 , 6467425
# 2021-11 , 6191080
# 2021-12 , 6265516
# 2022-01 , 5998112
# 2022-02 , 5991488
# 2022-03 , 6764384
# 2022-04 , 6635419
# 2022-05 , 6809512
# 2022-06 , 6646541
# 2022-07 , 6763067
# 2022-08 , 6721232
# 2022-09 , 6602439
# 2022-10 , 6912245
# 2022-11 , 6506716
# 2022-12 , 6832756
# 2023-01 , 6678980
# 2023-02 , 6272648
# 2023-03 , 7067397
# ...

# %%
new_file_paths = []
for year_month in year_month_list:
    new_file_path = r"C:\Users\EvanSpiller\Documents\DS BootCamp\Capstone\data\HVFHV_Compressed\compressed_HVFHV_" + year_month
    new_file_paths.append(new_file_path)
# Out:
# ['C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-02',
#  'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-03',
#  'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-04',
#  'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-05',
#  'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-06',
#  'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-07',
#  'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-08',
#  'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-09',
# ...

# %%
df1 = pd.read_parquet(new_file_paths[0])
df2 = pd.read_parquet(new_file_paths[1])
result_df = pd.concat([df1, df2], axis=0, ignore_index=True)

# %%
new_file_path_2019_2020 = ['C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-02',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-03',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-04',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-05',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-06',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-07',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-08',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-09',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-10',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-11',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2019-12',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-01',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-02',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-03',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-04',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-05',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-06',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-07',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-08',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-09',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-10',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-11',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2020-12',]

# %%
dfs_hvfhv = []

for file_path in new_file_path_2019_2020:
    df = pd.read_parquet(file_path)
    dfs_hvfhv.append(df)

# %%
full_compressed_HVFHV_2019_2020 = pd.concat(dfs_hvfhv, axis=0, ignore_index=True)

# %%
full_compressed_HVFHV_2019_2020.groupby('Month').sum() #just a check to make sure this can run in a reasonable amount of time
#answer: slow, but nothing crazy
# Out:
#        PULocationID  DOLocationID         Year        Day       Hour  \
# Month
# 1         929453932     937849650  13589209070  108679693   85432175
# 2        1814745163    1831716040  26565067544  194368147  167768624
# 3        1736585906    1754513399  25515367145  185448102  160853354
# 4        1325176948    1342302160  19542354543  151426230  123868618
# 5        1465054894    1484562758  21609134086  172197415  137061320
# 6        1506701462    1527091925  22206366989  174210099  139647182
# 7        1626908774    1647695788  23957234523  193090866  151965604
# 8        1689801747    1710440011  24865873172  197971061  158051946
# 9        1694665335    1715826701  24878155070  192379612  158552726
# 10       1760173898    1780727075  25777908894  205308602  164172046
# 11       1681259436    1701809713  24645046630  187183192  156346841
# 12       1693327147    1713624389  24846023295  195233712  158054937
#
# ...

# %%
full_compressed_HVFHV_2019_2020.to_parquet(r'C:\Users\EvanSpiller\Documents\DS BootCamp\Capstone\full_compressed_HVFHV_2019_2020', engine='pyarrow')

# %%
new_file_path_2021 =  ['C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-01',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-02',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-03',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-04',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-05',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-06',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-07',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-08',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-09',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-10',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-11',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2021-12']

# %%
dfs_hvfhv_2021 = []

for file_path in new_file_path_2021:
    df = pd.read_parquet(file_path)
    dfs_hvfhv_2021.append(df)

# %%
full_compressed_HVFHV_2021 = pd.concat(dfs_hvfhv_2021, axis=0, ignore_index=True)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\EvanSpiller\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\EvanSpiller\AppData\Local\Temp\ipykernel_19344\617562228.py", line 1, in <module>
#     full_compressed_HVFHV_2021 = pd.concat(dfs_hvfhv_2021, axis=0, ignore_index=True)
#   File "C:\Users\EvanSpiller\anaconda3\lib\site-packages\pandas\core\reshape\concat.py", line 385, in concat
#     return op.get_result()
#   File "C:\Users\EvanSpiller\anaconda3\lib\site-packages\pandas\core\reshape\concat.py", line 616, in get_result
#     new_data = concatenate_managers(
#   File "C:\Users\EvanSpiller\anaconda3\lib\site-packages\pandas\core\internals\concat.py", line 232, in concatenate_managers
#     values = np.concatenate(vals, axis=1)
# ...

# %%
full_compressed_HVFHV_2021.shape
# Out:
# (72968266, 11)

# %%
full_compressed_HVFHV_2021.to_parquet(r'C:\Users\EvanSpiller\Documents\DS BootCamp\Capstone\data\HVFHV_Compressed\Combined\full_compressed_HVFHV_2021', engine='pyarrow')

# %%
new_file_path_2022_2023 = ['C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-01',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-02',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-03',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-04',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-05',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-06',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-07',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-08',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-09',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-10',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-11',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2022-12',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2023-01',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2023-02',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2023-03',
 'C:\\Users\\EvanSpiller\\Documents\\DS BootCamp\\Capstone\\data\\HVFHV_Compressed\\compressed_HVFHV_2023-04']

# %%
dfs_hvfhv_2022_2023 = []

for file_path in new_file_path_2022_2023:
    df = pd.read_parquet(file_path)
    dfs_hvfhv_2022_2023.append(df)

# %%
full_compressed_HVFHV_2022_2023 = pd.concat(dfs_hvfhv_2022_2023, axis=0, ignore_index=True)

# %%
full_compressed_HVFHV_2022_2023.shape
# Out:
# (106028088, 11)
